# %% [markdown]
# <a href="https://colab.research.google.com/github/IsaacNascimento/ADS025/blob/master/Lista4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Questão 1

'''QtdeLados = int(input('Insira a quantidade da lados do polígno. (3) para Triângulo, (4) para Quadrado e (5) para Pêntagono: ')) # 1º linha recebe números inteiros, que são o número de lados de um polígno!
if QtdeLados<3 or QtdeLados>5: # 2º linha declara uma condições onde números'' inteiros menores que 3 e maiores que 5 são abordados.  
 while True: # 3º Laço, na qual é mantido por uma condição.
    print('Quantidade de lados inválido!') # 4º linha imprime "valor inválido" se o número inteiro entrar na condição da 2º linha.
    QtdeLados = int(input('Insira a quantidade da lados. (3) Triângulo, (4) Quadrado e (5) Pêntagono: ')) # 5º linha recebe números inteiros!
    if QtdeLados>=3 and QtdeLados<=5: # 6º linha declara uma condição, na qual se os números de entrada se encaixarem, o programa continuará. 
      break  # 7º linha quebra o laço se a condição da 6º linha for suprida.
alt = int(input('Insira a altura do Polígno (em cm²): ')) # 8º linha que recebe números inteiros, que são a altura de um polígno!
bas = int(input('Insira a base do Polígno (em cm²): '))   # 9º linha que recebe números inteiros, que são a base de um polígno!
if QtdeLados == 3: # 10º linha coloca uma condição de números de lados exatamente igual a 3.
    print('Triângulo') # 11º linha se a condição de cima for satisfeita, então irá imprimir "Triãngulo".
    Area = bas*alt/2 # 12º linha declara uma varíavel que condiz a respeito da fórmula da area do triângulo.
    print('A area do Triângulo é:',Area, 'cm²') # 13º linha imprime a area em centimetros.
elif QtdeLados == 4: # 14º linha coloca uma condição de números de lados exatamente igual a 4.
    print('Quadrado') # 15º linha se a condição de cima for satisfeita, então irá imprimir "Quadrado".
    Area2 = bas*alt # 16º linha declara uma varíavel que condiz a respeito da fórmula da area do quadrado.
    print('A area do Quadrado é:',Area2, 'cm²') # 17º linha imprime a area em centimetros.
else: # 18º linha se todas as condições acima não entrarem, então sobra somente essa que é o numero 5.
  print('Pentágono! A Area do Pentágono é', 5*bas*alt, 'cm²') # 19º linha imprime, e também apresenta o calculo da area do pentagono. Obs: Não sei exatamente se é essa a fórmula, pois tive dificuldade na execução desta parte do programa.'''

# Questão 2

'''QtdeLados = int(input('Insira a quantidade da lados. (3) Triângulo, (4) Quadrado e (5) Pêntagono: ')) # 1º linha recebe números inteiros, que são o número de lados de um polígno!
if QtdeLados<3 or QtdeLados>5: # 2º linha declara uma condições onde números inteiros menores que 3 e maiores que 5 são abordados.  
  while True: # 3º Laço, na qual é mantido por uma condição.
      if QtdeLados<3:
       print('NÃO É UM POLÍGONO.')
      elif  QtdeLados>5:
       print('r POLÍGONO NÃO IDENTIFICADO.')
      else:
       break
       if QtdeLados
  while True:
       print('Quantidade de lados inválido!') # 4º linha imprime "valor inválido" se o número inteiro entrar na condição da 2º linha.
       QtdeLados = int(input('Insira a quantidade da lados. (3) Triângulo, (4) Quadrado e (5) Pêntagono: ')) # 5º linha recebe números inteiros!
       if QtdeLados>=3 and QtdeLados<=5: # 6º linha declara uma condição, na qual se os números de entrada se encaixarem, o programa continuará. 
        break  # 7º linha quebra o laço se a condição da 6º linha for suprida.
alt = int(input('Insira a altura do Polígno (em cm²): ')) # 8º linha que recebe números inteiros, que são a altura de um polígno!
bas = int(input('Insira a base do Polígno (em cm²): '))   # 9º linha que recebe números inteiros, que são a base de um polígno!
if QtdeLados == 3: # 10º linha coloca uma condição de números de lados exatamente igual a 3.
    print('Triângulo') # 11º linha se a condição de cima for satisfeita, então irá imprimir "Triãngulo".
    Area = bas*alt/2 # 12º linha declara uma varíavel que condiz a respeito da fórmula da area do triângulo.
    print('A area do Triângulo é:',Area, 'cm²') # 13º linha imprime a area em centimetros.
elif QtdeLados == 4: # 14º linha coloca uma condição de números de lados exatamente igual a 4.
    print('Quadrado') # 15º linha se a condição de cima for satisfeita, então irá imprimir "Quadrado".
    Area2 = bas*alt # 16º linha declara uma varíavel que condiz a respeito da fórmula da area do quadrado.
    print('A area do Quadrado é:',Area2, 'cm²') # 17º linha imprime a area em centimetros.
else: # 18º linha se todas as condições acima não entrarebas*alt/2 # 12º linha dem, então sobra somente essa que é o numero 5.
  print('Pentágono! A Area do Pentágono é', 5*bas*alt, 'cm²') # 19º linha imprime, e também apresenta o calculo da area do pentagono. Obs: Não sei exatamente se é essa a fórmula, pois tive dificuldade na execução desta parte do programa.'''

# Questão 3

'''Num1 = int(input('Insira o 1º número inteiro: ')) # Recebe o 1º numero inteiro
Num2 = int(input('Insira o 2º número inteiro: ')) # Recebe o 2º numero inteiro
Num3 = int(input('Insira o 3º número inteiro: ')) # Recebe o 3º numero inteiro
if Num1 == Num2 == Num3: # Condição que se os numeros forem iguais
  while True:
    print('Valores não podem ser iguais!') # Se eles forem iguais, o programa vai repetir até o usuário escrever numeros diferentes
    Num1 = int(input('Insira o 1º número inteiro: ')) # Recebe o 1º numero inteiro
    Num2 = int(input('Insira o 2º número inteiro: ')) # Recebe o 2º numero inteiro
    Num3 = int(input('Insira o 3º número inteiro: ')) # Recebe o 3º numero inteiro
    if Num3!=Num2!=Num1: # Condição que se os numeros forem diferentes, o programa segue
      break  
lista = [Num1, Num2, Num3] # Cria uma lista para agrupar os numeros inseridos
print('O maior valor é', max(lista), 'e o menor valor é', min(lista)) # Aqui imprime o menor e maior valor da lista'''


# Questão 4

'''Num1 = int(input('Insira a 1º medida do lado do triângulo: ')) # Recebe o 1º numero inteiro
Num2 = int(input('Insira a 2º medida do lado do triângulo: ')) # Recebe o 1º numero inteiro
Num3 = int(input('Insira a 3º medida do lado do triângulo: ')) # Recebe o 1º numero inteiro
if Num1 == Num2 == Num3: # Condição que iguala os numeros
  print('Triângulo Equilátero! Todos os lados são iguais!') # Se forem iguais imprime isso
elif Num3!=Num2!=Num1!=Num3: # Condição que difere os numeros
  print('Triângulo Escaleno! Todos os lados são diferentes!')  # Se forem diferentes imprime isso
else: # Sobra a alternativa de dois lados serem iguais
  print('Triângulo Isóscele! Dois lados iguais!') # Se 2 lados forem iguais imprime isso''' 

# Questão 5

'''Num1 = int(input('Insira o 1º ângulo do triângulo: ')) # Recebe o 1º numero inteiro
Num2 = int(input('Insira o 2º ângulo do triângulo: ')) # Recebe o 2º numero inteiro
Num3 = int(input('Insira o 3º ângulo do triângulo: ')) # Recebe o 3º numero inteiro
if Num1<90 and Num2<90 and Num3<90: # Se os numeros forem menores que 90
   print('Triângulo acutângulo!') # Se forem menores, se imprime isso
elif Num1>90 or Num2>90 or Num3>90: # Se os numeros forem maiores que 90
   print('Triângulo Obtusângulo!') # Se forem maiores, se imprime isso
else: # Se pelos menos um for igual a 90
   print('Triângulo Retângulo!') # Se imprime isso'''

# Questão 6

'''num = int(input('Insira um número inteiro: ')) # Recebe UM numero inteiro
soma=0 
for _ in range(0,num+1,1): 
  soma += _ # soma = soma + _
print('A soma dos valores impares até', num, 'é', soma) # Imprime isso
#Essa questão 6 tive muita dificuldade, na qual obviamente se encontra incompleta'''

# Questão 7

'''Num =  int(input('Insira um número inteiro de 1 a 4: ')) # Recebe UM numero inteiro
if Num<1 or Num>4: # Se for maior que 4 ou menor que 1
  while True: # laço
   print('Entrada inválida!') # Se o numero recebido se encaixar na condição acima, imprime isso
   Num =  int(input('Insira um número de 1 a 4: '))  # Recebe UM numero inteiro
   if Num>=1 and Num<=4: # Se for maior ou igual a 1 ou menor igual a 1
     break # Então quebra o laço e continua o programa
print(Num) #Imprime o numero digitado'''

# Questão 8

'''Num1 =  int(input('Insira o 1º número inteiro! (Insira 0 para sair): ')) # Recebe o 1º numero inteiro
Num2 =  int(input('Insira o 2º número inteiro!    (Insira 0 para sair): ')) # Recebe o 2º numero inteiro
Num3 =  int(input('Insira o 3º número inteiro!    (Insira 0 para sair): ')) # Recebe o 3º numero inteiro
Num4 =  int(input('Insira o 4º número inteiro!    (Insira 0 para sair): ')) # Recebe o 4º numero inteiro
if Num1 == 0 and Num2 == 0and Num3 == 0 and Num4 == 0: # Se os numeros digitados forem igual a 0
  while True: # laço
    break # Se forem iguais, o programa é interrompido
lista = [Num1, Num2, Num3, Num4] # lista para agrupar os numeros recebidos
print('O maior valor é', max(lista), 'e o menor valor é', min(lista)) # Imprime o maior e menor valor digitado na lsta''' 


# Questão 9

'''Num =  int(input('Insira um número inteiro de 4 digítos (Ex: 9999): ')) # Recebe um número
if Num<1000 or Num>9999: # Se o numero for menor que 1000 e maior que 9999
  while True: # laço
    print('Valor inválido!') # Se encaixar na condição acima, então imprime isso
    Num =  int(input('Insira um número inteiro de 4 digítos (Ex: 9999): ')) # Recebe um número
    if Num>=1000 and Num<=9999: # Se o numero for maior ou igual a 1000 e menor ou igual a 9999
     break # Então quebra o laço e o programa proseguirá
A = str(Num) # Transforma o numero em string, pois é mais facil de concatenar
print('Analisando o número {}'.format(Num)) # Imprime o numero recebido
print('Unidade: {}'.format(A[3])) # Imprime a quarta posição do numero
print('Dezena: {}'.format(A[2])) # Imprime a terceira posição do numero
print('Centena: {}'.format(A[1])) # Imprime a segunda posição do numero
print('Milhar: {} '.format(A[0])) # Imprime a primeira posição do numero'''

# Questão 10


'''import statistics  # Biblioteca para impregar métodos
Num1 =  int(input('Insira o 1º número inteiro!  (Insira 0 para sair): ')) # Recebe um numero
if Num1 == 0: Se o numero digitado for igual a 0
  while True: # Laço
    break # Programa interrompido se encaixar na condição acima
Num2 =  int(input('Insira o 2º número inteiro!  (Insira 0 para sair): ')) # Recebe um numero
if Num2 == 0: # Se o numero digitado for igual a 0
  while True: # Laço
    break # Programa interrompido se encaixar na condição acima
Num3 =  int(input('Insira o 3º número inteiro!  (Insira 0 para sair): '))  # Recebe um numero
if Num3 == 0: # Se o numero digitado for igual a 0
  while True: # Laço
    break # Programa interrompido se encaixar na condição acima
Num4 =  int(input('Insira o 4º número inteiro!  (Insira 0 para sair): ')) # Recebe um numero
if Num4 == 0: # Se o numero digitado for igual a 0
  while True: # Laço
    break   # Programa interrompido se encaixar na condição acima
lista = [Num1, Num2, Num3, Num4] # lista para agrupar os numeros recebidos
MediaSimples = statistics.mean(lista) # Media simples dos numeros recebidos
print('A média simples é', round(MediaSimples,2)) # Imprime a media da linha acima
from scipy.stats.mstats import gmean #  Biblioteca para impregar métodos
MediaGeom = gmean(lista) #  Media geometrica dos numeros recebidos
print('A média geométrica é', round(MediaGeom,2)) # Imprime a media da linha acima
MediaHarm = statistics.harmonic_mean(lista) #  Media harmônica dos numeros recebidos
print('A média harmônica é', round(MediaHarm,2)) # Imprime a media da linha acima
MediaPond = Num1*2 + Num2*3 + Num3*4 + Num4*5/14 # Media ponderada dos numeros recebidos
print('A média ponderada é', round(MediaPond,2)) # Imprime a media da linha acima'''
# Out:
# Digite a quantidade de lados: 4
# Digite a medida do lado: 3
# A figura é um Quadrado!
# A área é: 9.00cm²
